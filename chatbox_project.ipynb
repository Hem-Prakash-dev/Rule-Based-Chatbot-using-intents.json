# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

text = "Hello Hem bhai, how are you?"
tokens = word_tokenize(text)
print("Tokens:", tokens)

lemmatizer = WordNetLemmatizer()
lemma = lemmatizer.lemmatize("running", pos="v")
print("Lemma:", lemma)
# Out:
# Tokens: ['Hello', 'Hem', 'bhai', ',', 'how', 'are', 'you', '?']
# Lemma: run

# %% [markdown]
# ## A) First, Dataset (Intents (Custom Dataset))

# %%
{
  "intents": [
    {
      "tag": "greeting",
      "patterns": ["Hi", "Hello", "Hey", "Good morning", "Good evening", "What's up?", "How's it going?"],
      "responses": ["Hello! How can I assist you today?", "Hi there!", "Hey! What's up?"]
    },
    {
      "tag": "goodbye",
      "patterns": ["Bye", "See you later", "Goodbye", "I am leaving", "Catch you later", "Talk to you soon"],
      "responses": ["Goodbye!", "See you soon!", "Have a nice day!"]
    },
    {
      "tag": "thanks",
      "patterns": ["Thanks", "Thank you", "That's helpful", "Thanks a lot", "Thank you so much"],
      "responses": ["You're welcome!", "Glad I could help!", "Anytime!", "No problem!"]
    },
    {
      "tag": "feeling",
      "patterns": ["How are you?", "How's everything?", "How do you feel?"],
      "responses": ["I'm a bot, but I'm doing great! How about you?", "I'm always ready to chat!"]
    },
    {
      "tag": "name",
      "patterns": ["What is your name?", "Who are you?", "Tell me your name"],
      "responses": ["I'm your friendly chatbot!", "You can call me Chatbot!", "I'm Hem's Chatbot."]
    },
    {
      "tag": "age",
      "patterns": ["How old are you?", "What is your age?", "When were you created?"],
      "responses": ["I'm timeless!", "I was created recently to assist you.", "Age is just a number!"]
    },
    {
      "tag": "weather",
      "patterns": ["What's the weather like?", "Is it raining?", "Tell me the weather today"],
      "responses": ["It's always sunny in my world!", "Weather looks nice outside.", "It might rain today, carry an umbrella."]
    },
    {
      "tag": "order_food",
      "patterns": ["I want to order food", "Order pizza", "Can I get a burger?", "I'd like to place a food order"],
      "responses": ["Sure, What would you like to order?", "I can help you order food!"]
    },
    {
      "tag": "noanswer",
      "patterns": [],
      "responses": ["Sorry, I didn't understand that. Can you rephrase?", "I'm not sure I follow."]
    }
  ]
}

# %% [markdown]
# ## B) Build Model (train_chatbot.py)

# %%
# train_chatbot.py

import json
import numpy as np
import random
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import nltk
from nltk.stem import WordNetLemmatizer
import pickle

# Download NLTK data
nltk.download('punkt')
nltk.download('wordnet')

# Initialize
lemmatizer = WordNetLemmatizer()

# Load intents
with open('intents.json') as file:
    data = json.load(file)

# Preparing data
training_sentences = []
training_labels = []
labels = []
responses = {}

for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    
    responses[intent['tag']] = intent['responses']

    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Encode labels
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# Tokenize and lemmatize sentences
def tokenize(sentence):
    tokens = nltk.word_tokenize(sentence)
    return [lemmatizer.lemmatize(w.lower()) for w in tokens]

all_words = []
for sentence in training_sentences:
    all_words.extend(tokenize(sentence))

all_words = sorted(set(all_words))

X_train = []
for sentence in training_sentences:
    bag = []
    words = tokenize(sentence)
    for w in all_words:
        bag.append(1) if w in words else bag.append(0)
    X_train.append(bag)

X_train = np.array(X_train)
y_train = np.array(training_labels)

# Build model
model = Sequential()
model.add(Dense(128, input_shape=(len(X_train[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(labels), activation='softmax'))

# Compile model
optimizer = Adam(learning_rate=0.01)
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=200, batch_size=8, verbose=1)

# Save model in new Keras format
model.save('chatbot_model.keras')

# Save other files
pickle.dump(all_words, open('words.pkl', 'wb'))
pickle.dump(lbl_encoder, open('labels.pkl', 'wb'))

print("Model trained and saved successfully in .keras format!")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0693 - loss: 2.19962.19
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2445 - loss: 1.9898
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4097 - loss: 1.8078
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6116 - loss: 1.4509
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5561 - loss: 1.3416
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7653 - loss: 1.1305
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6555 - loss: 0.9019
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7868 - loss: 0.6998
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8184 - loss: 0.6583
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 0.4443
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9359 - loss: 0.2997
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9254 - loss: 0.2967
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8624 - loss: 0.4693
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9313 - loss: 0.1846
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8786 - loss: 0.3700
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7595 - loss: 0.3831
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8254 - loss: 0.4999
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1388
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8983 - loss: 0.2728
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.1342
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9318 - loss: 0.1501
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1832
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8820 - loss: 0.1901
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.2163
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0964
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0654
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9337 - loss: 0.1510
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0660
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9850 - loss: 0.0892
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0633
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0609
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1831
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9850 - loss: 0.0609
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8820 - loss: 0.2367
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0606
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0495
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0331
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.1611
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.1139
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0556
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9526 - loss: 0.1244
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0345
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0416
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0546
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0527
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0292
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0282
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9331 - loss: 0.1395
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0407
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0144  -
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9510 - loss: 0.0839
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0187  -
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0310
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.0738
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0408
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.1428
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0149
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0309
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0225
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.1040
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0811
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0182
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0565
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9700 - loss: 0.0891
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0063
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.1822e-04
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.02454e-
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0285
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9850 - loss: 0.1026
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0097
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0321
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9759 - loss: 0.0771
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1253
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9680 - loss: 0.10503e-
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0241
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.3064e-04
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0373
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.7616e-04
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.002317
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0119  e-
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.0277  -
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9850 - loss: 0.0827
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9144 - loss: 0.1181
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0556  -
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.5652e-04
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0881
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0289
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0611
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0398 -
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9248 - loss: 0.1223
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9829 - loss: 0.0858
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.0441
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.2728
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.0499
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.019169
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0103
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.1991e-04
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0534
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.1839e-04
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.0924
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0169
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.0587
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 6.7812e-04
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0190
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.0847
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.0352
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.01993e-
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0209
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9676 - loss: 0.0330
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0435
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.0582
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9318 - loss: 0.1059
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.1665e-04
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.005217e-
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9850 - loss: 0.01782-0
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.8210e-04
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.8969e-05
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5971e-04
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9144 - loss: 0.2434
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.2745
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.5737e-04
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0360
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9676 - loss: 0.0379
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.0621
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.00136e-
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.1943e-04
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.0880e-04
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.8520e-04
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.4416e-04
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9578 - loss: 0.0937
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.5637e-04
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.1352
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9681 - loss: 0.0320
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9370 - loss: 0.1816
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0325
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3850e-04
# Model trained and saved successfully in .keras format!

# %% [markdown]
# ## C) Chatbot Core Logic (chatbot.py)

# %%
import random
import pickle
import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import load_model
import numpy as np

# Download NLTK data
nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

# Load the trained model
model = load_model('chatbot_model.keras')  # Make sure to load the correct model format
# Load the other assets (words and labels)
with open('words.pkl', 'rb') as f:
    all_words = pickle.load(f)

with open('labels.pkl', 'rb') as f:
    lbl_encoder = pickle.load(f)

# Load intents
with open('intents.json') as file:
    intents = json.load(file)

# Function to clean and process text input
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word.lower()) for word in tokens]
    return tokens

# Function to create a bag of words for prediction
def bag_of_words(text):
    tokens = clean_text(text)
    bag = [0] * len(all_words)
    for s in tokens:
        for i, word in enumerate(all_words):
            if word == s:
                bag[i] = 1
    return np.array(bag)

# Predict the intent of the user's input
def predict_intent(text):
    bow = bag_of_words(text)  # Create bag of words
    prediction = model.predict(np.array([bow]))  # Predict using the model
    intent_index = np.argmax(prediction)  # Get the index of the highest probability
    confidence = prediction[0][intent_index]  # Get the confidence of the prediction
    intent = lbl_encoder.inverse_transform([intent_index])[0]  # Map index to intent tag
    return intent, confidence

# Get a response based on the predicted intent
def get_response(intent_tag):
    for intent in intents['intents']:
        if intent['tag'] == intent_tag:
            return random.choice(intent['responses'])
    return "I am not sure how to answer that."

# Main function to get the chatbot's response
def chatbot_response(user_input):
    intent, confidence = predict_intent(user_input)
    if confidence > 0.6:
        return get_response(intent)
    else:
        return get_response("noanswer")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## D) GUI Integration (gui.py)

# %%
import random
import json
import pickle
import numpy as np
import tkinter as tk
from tkinter import Scrollbar, Text, Entry, Button, END
from tensorflow.keras.models import load_model
import nltk
from nltk.stem import WordNetLemmatizer

# Initialize
lemmatizer = WordNetLemmatizer()

# Load Files
model = load_model('chatbot_model.keras')  # Correct model file
intents = json.loads(open('intents.json', encoding='utf-8').read())
words = pickle.load(open('words.pkl', 'rb'))
labels = pickle.load(open('labels.pkl', 'rb'))

def tokenize(sentence):
    tokens = nltk.word_tokenize(sentence)
    return [lemmatizer.lemmatize(word.lower()) for word in tokens]

def bag_of_words(sentence):
    tokens = tokenize(sentence)
    bag = [0] * len(words)
    for s in tokens:
        for i, word in enumerate(words):
            if word == s:
                bag[i] = 1
    return np.array(bag)

def chatbot_response(text):
    bow = bag_of_words(text)
    res = model.predict(np.array([bow]))[0]
    threshold = 0.4  # Lowered the threshold for more varied responses
    results = [[i, r] for i, r in enumerate(res) if r > threshold]

    if results:
        results.sort(key=lambda x: x[1], reverse=True)
        tag = labels.inverse_transform([results[0][0]])[0]  # Fixed this line

        for intent in intents['intents']:
            if intent['tag'] == tag:
                return random.choice(intent['responses'])

    return "I didn't get that. Can you rephrase?"

# GUI Setup
root = tk.Tk()
root.title("Hem's AI Chatbot")
root.geometry("500x600")
root.configure(bg="#17202A")

# Chat window
chat_log = Text(root, bd=1, bg="#2C3E50", fg="#EAECEE", font=("Helvetica", 14), wrap='word')
chat_log.pack(padx=10, pady=10, fill=tk.BOTH, expand=True)

scrollbar = Scrollbar(chat_log)
scrollbar.place(relheight=1, relx=0.974)
scrollbar.config(command=chat_log.yview)
chat_log['yscrollcommand'] = scrollbar.set
chat_log.config(state=tk.DISABLED)

# Entry box
entry_frame = tk.Frame(root, bg="#17202A")
entry_frame.pack(padx=10, pady=10, fill=tk.X)

entry_box = Entry(entry_frame, bd=1, bg="#2C3E50", fg="#EAECEE", font=("Helvetica", 14))
entry_box.pack(side=tk.LEFT, fill=tk.X, expand=True, padx=(0, 10))

def send_message(event=None):
    msg = entry_box.get().strip()
    if msg == "":
        return

    chat_log.config(state=tk.NORMAL)
    chat_log.insert(END, "You: " + msg + "\n\n")
    entry_box.delete(0, END)

    res = chatbot_response(msg)
    chat_log.insert(END, "Bot: " + res + "\n\n")

    chat_log.config(state=tk.DISABLED)
    chat_log.yview(END)

send_button = Button(entry_frame, text="Send", font=("Helvetica", 13, "bold"), bg="#ABB2B9", command=send_message)
send_button.pack(side=tk.RIGHT)

# Bind Enter key to send message
root.bind('<Return>', send_message)

root.mainloop()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
